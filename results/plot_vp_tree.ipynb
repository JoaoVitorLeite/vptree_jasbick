# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import io
import seaborn as sns
from os import listdir
from os.path import isfile, join
# %matplotlib inline

# %%
def readResults(path, group):
    onlyfiles = [join(path,f) for f in listdir(path) if isfile(join(path, f))]
    info_pivots = {}
    query_data = []
    label = []
    
    for path in onlyfiles:
        try:
            file = open(path)
            lines = file.readlines()
            data = [line.rstrip().split(",") for line in lines]
            key = data[0][2]
            data[0].pop(2)
            value = data[0]
            info_pivots[key] = value
            data.pop(0)

            data[0] = ["Pivot"] + data[0]

            for i in range(1, len(data)):
                data[i] = [key] + data[i]

            label = data[0]
            data.pop(0)

            query_data.extend(data)

        finally:
            file.close()
    
    query_data.insert(0, label)
    data = [" ".join(line) for line in query_data]
    df = pd.read_csv(io.StringIO('\n'.join(data)), delim_whitespace=True)
    df.columns = ["Pivot", "K", "Time", "Distance Count"]
    
    if group:
        group_df = df.groupby(["Pivot", "K"])[["Distance Count"]].median().reset_index()
        return group_df
    else:
        return df

# %%
df = readResults("ulcer_vptree/", True)

# %%
df
# Out:
#               Pivot    K  Distance Count
# 0    0x555976deadb0    5           321.0
# 1    0x555976deadb0   10           321.0
# 2    0x555976deadb0   15           321.0
# 3    0x555976deadb0   20           321.0
# 4    0x555976deadb0   25           321.0
# ..              ...  ...             ...
# 175  0x5613bee53db0   80           321.0
# 176  0x5613bee53db0   85           321.0
# 177  0x5613bee53db0   90           321.0
# 178  0x5613bee53db0   95           321.0
# 179  0x5613bee53db0  100           321.0
#
# [180 rows x 3 columns]
